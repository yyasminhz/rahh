# %% [markdown]
# <a href="https://colab.research.google.com/github/yyasminhz/rahh/blob/main/BIOPAL_Group_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exploring the Relationship Between Depression Severity (PHQ-9 scores) and Physiological Biomarkers (SLD010H, BPXPLS, LBXCRP) in Adults: a NHANES 2007–2018 Study by Gender and Ethnicity**

# %% [markdown]
# Group member: Yasmin S10267172J
# Class: BMS P02
# Link to GitHub repo:  https://github.com/yyasminhz/rahh/blob/main/BIOPAL_Group_8.ipynb
# Link to Google Colab: https://colab.research.google.com/drive/1EQsmhrpDR0Ln_-r2gnnxTd55tpIw17Mo?usp=sharing

# %% [markdown]
# # **Summary**

# %% [markdown]
# This study aims to explore the relationship between depression severity (measured using the Patient Health Questionnaire-9 aka PHQ-9 ) and key physiological biomarkers including sleep duration (SLD010H), resting heart rate (BPXPLS), and C-reactive protein levels (LBXCRP) using data from the NHANES 2007–2018 cycles. In addition to examining these biomarkers, the study investigates the role of several independent variables—namely age, gender, ethnicity, smoking status, physical activity level, haemoglobin, and total cholesterol—as potential predictors of depression severity.
#
# The analysis will be stratified by gender and ethnicity to identify potential disparities in the biological and behavioral factors associated with depressive symptoms across diverse populations. By integrating both physiological and demographic variables, this study seeks to provide a more comprehensive understanding of the biological and lifestyle correlates of depression in U.S. adults.

# %% [markdown]
# # **Background and rationale**

# %% [markdown]
# ##**4.1 Health Issue**
# Depression is recognized as a leading cause of disability worldwide, according to the World Health Organization (WHO). It is a major contributor to the global burden of disease and significantly impairs an individual’s ability to function socially, emotionally, and physically. In the United States, depression affects millions of adults annually, with disparities observed across gender and ethnic groups.
#
# While psychological and environmental factors in depression are well established, growing evidence suggests that biological markers may also play a role. Exploring these physiological and demographic correlates is essential to better understand the underlying complexity of depression and how it manifests in different populations.

# %% [markdown]
# ## **4.2 Importance**
#
# This study is important because it addresses a critical gap in understanding how biological and lifestyle factors interact with depression severity in the general population. By using nationally representative data from NHANES, the study provides insights that are both population-relevant and clinically meaningful. The inclusion of physiological biomarkers such as sleep duration, resting heart rate, and C-reactive protein alongside demographic and behavioral predictors enables a more holistic view of depression beyond self-reported symptoms alone.
#
# Identifying potential physiological patterns linked to depressive severity can contribute to the development of early warning systems, especially for individuals who may not have access to regular mental health screenings. Additionally, by examining these relationships across gender and ethnic subgroups, the study supports efforts toward more equitable and culturally sensitive healthcare practices. In the long term, these findings may inform public health strategies aimed at integrating physical and mental health care, and guide research into biomarker-based screening or prevention tools.

# %% [markdown]
# ## **4.3 PubMed Literature Support**
#
# Studies have reported significant links between depression and elevated CRP levels, suggesting systemic inflammation may contribute to depressive symptomatology. For example, Shin, L. M., Kim, H. J. & Lee, S. Y. (2016) found that U.S. adults with depressive symptoms had significantly higher CRP levels, even after adjusting for lifestyle and demographic factors. Similarly, Howren, M. B., Lamkin, D. M. & Suls, J. (2009) reported significant associations between depression and CRP (d = 0.15, 95% CI 0.10–0.21, p < .001), reinforcing a systemic inflammation hypothesis in depression.
#
# Additionally, Kroenke, K., Spitzer, R. L. & Williams, J. B. W. (2001) validated the PHQ-9 as a reliable, continuous measure of depression severity, allowing researchers to study symptom gradation rather than binary diagnoses.

# %% [markdown]
# ## **4.4 Use of NHANES**
# While previous studies have suggested potential links between depression and biological factors like sleep disturbances, cardiovascular changes, and systemic inflammation, many of these findings have been limited by narrow demographic focus, small sample sizes, or lack of standardized national data.
# By using data from the National Health and Nutrition Examination Survey (NHANES) 2007–2018, which is a nationally representative U.S. dataset, this study offers several important contributions:
# 1. This study builds upon prior evidence linking depression to physiological markers but extends the analysis to a nationally representative population of adults aged 18–65 years
# 2. While sleep and inflammation have been individually linked to depression, this study simultaneously analyses sleep duration (SLD010H), heart rate (BPXPLS), and CRP (LBXCRP), offering a more integrated biological perspective on mental health.
# 3. The inclusion of gender, age, and race/ethnicity allows for stratified or adjusted analyses, helping to uncover potential disparities or population-specific trends in depression and its biological correlates.
# 4. By correlating subjective depression scores (PHQ-9) with objective physiological measures, the study may contribute to the development of multi-modal screening approaches or personalized interventions.

# %% [markdown]
# # **Reasearch questions and objectives**

# %% [markdown]
# ## **5.1 Research question**
# “How does depression severity, measured by PHQ-9 scores, correlate with physiological biomarkers (CRP, Heart Rate, Sleeping Hours) in adults aged 18–65, and do these associations differ by gender and ethnicity?”

# %% [markdown]
# ## **5.2 Justification of Novelty**
# Depression has been increasingly recognized as a condition with physiological components beyond psychological symptoms. Prior research has linked elevated levels of C-reactive protein (CRP), an inflammatory marker, with depression severity. For example, Shin et al. (2016) analysed NHANES 2007–2012 data and found that individuals with depression had significantly higher CRP levels, even after adjusting for confounders. Similarly, Howren, Lamkin & Suls (2009) conducted a meta-analysis of 24 studies and reported significant associations between depression and inflammatory markers, including CRP (r = 0.12, p < 0.001). reinforcing the role of systemic inflammation in depressive disorders.
#
#
# However, most of these studies focused either on a single biomarker, such as CRP, or a binary classification of depression (i.e., depressed vs. non-depressed), rather than a continuous score. Additionally, the role of blood components (HGB) and cardiovascular indicators (pulse rate) in depression has received limited attention. Moreover, existing studies often fail to explore how these relationships differ by gender and ethnicity, despite known demographic disparities in both depression prevalence and biomarker levels.

# %% [markdown]
# ## **5.3 How this Project Fills Knowledge Gaps**
# This study builds on the existing body of research by:
# 1. Using PHQ-9 as a continuous variable to better capture gradations in depression severity;
# 2. Including multiple physiological biomarkers (cholesterol, HGB and CRP) across inflammatory, hepatic, and cardiovascular systems;
# 3. Stratifying results by gender and ethnicity, thus allowing for more nuanced and equitable public health insights;
# Together, these design choices address the gaps in scope, methodology, and subgroup analysis seen in prior studies.

# %% [markdown]
# ## **5.4 SMART Objectives**
#
#  | Objective | SMART Criteria |
# | --- | --- |
# | **To determine the association between PHQ-9 depression severity scores and C-reactive protein (CRP) levels in adults aged 18–65, and assess whether this association differs by gender and race/ethnicity.** | - **Specific:** This objective focuses on whether higher CRP (inflammation marker) levels are linked to higher PHQ-9 depression scores, and whether this relationship differs for males and females or across ethnic groups.<br>- **Measurable:** Multiple linear regression and group comparisons (e.g., Kruskal–Wallis test) will be used to test the association and compare across gender and race.<br>- **Achievable:** CRP data are available for some years (2007–2009, 2015–2018), and the cleaned dataset has enough participants for subgroup analysis.<br>- **Relevant:** Inflammation is a known factor in depression, and this objective helps explore how it varies across different groups.<br>- **Time-Bound:** All work can be completed within the project window (approximately 6 weeks). |
# | **To assess the relationship between depression severity (PHQ-9 scores) and resting heart rate (BPXPLS) among adults aged 18–65, adjusting for physical activity level and smoking status.** | - **Specific:** This objective focuses on determining whether increased resting heart rate is associated with higher PHQ-9 scores, while accounting for the influence of physical activity and smoking—two known modulators of heart rate and mood.<br>- **Measurable:** Multiple linear regression models will be used to assess associations, including interaction terms and adjustments for covariates (e.g., physical activity, smoking).<br>- **Achievable:** BPXPLS, physical activity, smoking status, and PHQ-9 data are available for relevant NHANES cycles, with sufficient sample size for analysis.<br>- **Relevant:** Resting heart rate reflects autonomic nervous system function, which is often altered in depression; understanding this relationship may support non-invasive screening tools.<br>- **Time-Bound:** Analysis and interpretation can be completed within the 6-week project timeline. |
# | **To examine the association between sleep duration (SLD010H/derived) and PHQ-9 scores in adults aged 18–65, and explore whether gender moderates this relationship.** | - **Specific:** This objective investigates whether sleep duration is linked to depression severity, and whether this relationship differs between males and females.<br>- **Measurable:** Linear regression will be used to model the relationship, with an interaction term (sleep × gender) to assess moderation. Descriptive statistics and subgroup analysis will also be conducted.<br>- **Achievable:** Sleep duration and gender data are widely available in NHANES cycles alongside PHQ-9 scores, with sufficient representation across groups.<br>- **Relevant:** Both sleep disturbances and gender differences are well-established factors in depression; this analysis may help inform tailored interventions.<br>- **Time-Bound:** The analysis, including interaction testing and subgroup exploration, is feasible within the 6-week study period. |

# %% [markdown]
# # **Variables and Data Sources**
#
# - **Dataset/timeframe**: NHANES 2007–2018
# - **Total number of participants**:
# - **Inclusion criteria**:
#   - **Age**: 18–65
#
# ### Dependent Variables
#
# | Biomarker       | NHANES Variable | Type       | Clinical Thresholds / Notes |
# |-----------------|------------------|------------|------------------------------|
# | **PHQ-9 score** | NIL              | Continuous | 0–27 scale; ≥10 indicates moderate-severe depression<br>PHQ-9 score is calculated by summing 9 individual items from the NHANES Depression Screener (DPQ) questionnaire |
# | **Sleep duration** | SLD010H (2007–2014)<br>Computed from SLQ300 & SLQ310 (2015–2018) | Continuous | Normal = 7–9 hrs; <6 or >9 = potential risk (CDC guideline)
# | **Heart rate**  | BPXPLS           | Continuous | Normal: 60–100 bpm; <60 = bradycardia, >100 = tachycardia |
# | **CRP**         | LBXCRP (2007–2009)<br>LBXHCRP (2015–2018) | Continuous | Normal <1 mg/L; 1–3 = moderate risk; >3 = high inflammation (AHA/CDC)<br>No CRP data available for 2010–2014. |
#
# ### Independent Variables
# | Demographic        | Variable | Mapping / Notes | Clinical Significance |
# |--------------------|----------|-----------------|-----------------------|
# | **Age**            | RIDAGEYR | Filter: 40–60 years | Used to evaluate if risk factors differentially impact on persons of different age. |
# | **Gender**         | RIAGENDR | 1 = Male, 2 = Female | Used to evaluate if risk factors differentially impact on persons of different gender. |
# | **Race/Ethnicity** | RIDRETH1 | 1 = Mexican American<br>2 = Other Hispanic<br>3 = Non-Hispanic White<br>4 = Non-Hispanic Black<br>5 = Other race, including Multiracial | Used to evaluate if risk factors differentially impact on persons of different race/ethnicity. |
# | **Smoking status** | SMQ020 | “Have you smoked at least 100 cigarettes in your entire life?”<br>1 = Yes, 2 = No<br>7 = Refused, 9 = Don’t know | Used to evaluate if smoking contributes to increased inflammation, altered physiological biomarkers, and depression severity, potentially confounding associations. |
# | **Physical activity** | PAD680 | `PAD680` measures daily sitting time (hours). Recoded to 4-level       **ActivityLevel**:<br>≤ 3 h → AL4 (Very active)<br>> 3–6 h → AL3 (Active)<br>> 6–9 h → AL2 (Low activity)<br>> 9 h → AL1 (Sedentary)<br>7777 or 9999 → NaN (Missing/invalid) | Used to evaluate if physical activity levels influence physiological health (e.g., CRP, HR) and depression severity, with lower activity possibly linked to worse outcomes. |
# | **Cholesterol**    | LBXTC | Unit: mg/dL<br>Normal range: ~125–200 mg/dL | Used to evaluate if cholesterol levels are associated with cardiovascular health and depression severity, as both high and low levels may affect mental and physical health. |
# | **Haemoglobin**    | LBXHGB | Unit: g/dL<br>Normal range:<br>• ~13.5–17.5 g/dL (men)<br>• ~12.0–15.5 g/dL (women) | Used to evaluate if haemoglobin levels (e.g., anemia) influence depressive severity. |

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# -----------------------------
# Step 0: Define years and NHANES cycles
# -----------------------------
years  = ["2007","2009","2011","2013","2015","2017"]
cycles = ["E","F","G","H","I","J"]
cycle_map = {"E":5, "F":6, "G":7, "H":8, "I":9, "J":10}

# Helper function to load XPT with fallback extensions
def load_xpt(year, cycle, prefix):
    for ext in ['XPT', 'xpt']:
        url = f"https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/{year}/DataFiles/{prefix}_{cycle}.{ext}"
        try:
            df = pd.read_sas(url, format='xport', encoding='utf-8')
            return df
        except Exception:
            continue
    raise RuntimeError(f"Unable to load {prefix} file for {year} cycle {cycle}")


# -----------------------------
# Step 1: Import and filter demographics
# -----------------------------
demo_dfs = []
for year, cycle in zip(years, cycles):
    df = load_xpt(year, cycle, 'DEMO')
    # Tag with both the raw cycle code and the actual start‐year
    df['SDDSRVYR'] = cycle_map[cycle]    # 5 → 2007–08, 6 → 2009–10, etc.
    df['Year']      = int(year)          # 2007, 2009, …
    demo_dfs.append(df)

# Concatenate into one raw DEMO
df_demo_raw = pd.concat(demo_dfs, ignore_index=True)

# Now filter by age but keep those two columns
df_demo = (
    df_demo_raw
      .query('RIDAGEYR >= 18 and RIDAGEYR <= 65')
      [['SEQN','RIAGENDR','RIDRETH1','RIDAGEYR','INDFMPIR','SDDSRVYR','Year']]
)

# -----------------------------
# Step 2: Import Smoking History (SMQ020, SMQ040)
# -----------------------------
smk_dfs = [load_xpt(year, cycle, 'SMQ') for year, cycle in zip(years, cycles)]
df_smq = pd.concat(smk_dfs, ignore_index=True)[['SEQN', 'SMQ020']]

# Concatenate and select smoking variables
df_smq = pd.concat(smk_dfs, ignore_index=True)
df_smq = df_smq[['SEQN', 'SMQ020']]

# -----------------------------
# Step 3: Import cholesterol (LBXTC)
# ----------------------------
tchol_dfs = [load_xpt(year, cycle, 'TCHOL') for year, cycle in zip(years, cycles)]
df_tchol = pd.concat(tchol_dfs, ignore_index=True)[['SEQN', 'LBXTC']]

# -----------------------------
# Step 4: Import haemoglobin (LBXHGB)
# ----------------------------
hgb_dfs = [load_xpt(year, cycle, 'CBC') for year, cycle in zip(years, cycles)]
df_hgb = pd.concat(hgb_dfs, ignore_index=True)[['SEQN', 'LBXHGB']]

# -----------------------------
# Step 5: Import heart rate (BPXPLS)
# ----------------------------
hr_dfs = [load_xpt(year, cycle, 'BPX') for year, cycle in zip(years, cycles)]
df_hr = pd.concat(hr_dfs, ignore_index=True)[['SEQN', 'BPXPLS']]

# -----------------------------
# Step 6: Import sleep hours (SLD010H, SLQ300, SLQ310)
# ----------------------------

sleep_dfs = []
for year, cycle in zip(years, cycles):
    df_cycle = load_xpt(year, cycle, 'SLQ')
    if cycle in ['E','F','G','H']:
        tmp = df_cycle[['SEQN','SLD010H']].rename(columns={'SLD010H':'SleepHours'})
    else:
        tmp = df_cycle[['SEQN','SLQ300','SLQ310']].copy()
        # parse the 'HH:MM' strings into datetime
        tmp['sleep_dt'] = pd.to_datetime(tmp['SLQ300'], format='%H:%M', errors='coerce')
        tmp['wake_dt']  = pd.to_datetime(tmp['SLQ310'], format='%H:%M', errors='coerce')
        # compute hours slept, adjust negative values (overnight)
        tmp['SleepHours'] = (tmp['wake_dt'] - tmp['sleep_dt']).dt.total_seconds() / 3600
        tmp.loc[tmp['SleepHours'] < 0, 'SleepHours'] += 24
        tmp = tmp[['SEQN','SleepHours']]
    sleep_dfs.append(tmp)

df_sleep = pd.concat(sleep_dfs, ignore_index=True)
# -----------------------------
# Step 7: Import activity level (PAD680)
# ----------------------------

act_dfs = [load_xpt(year, cycle, 'PAQ') for year, cycle in zip(years, cycles)]
df_act = pd.concat(act_dfs, ignore_index=True)[['SEQN', 'PAD680']]

# Ensure PAD680 is numeric (minutes)
df_act['PAD680'] = pd.to_numeric(df_act['PAD680'], errors='coerce')

# Recode PAD680 (minutes) to hours and classify into 4 levels:
#   < 3 hrs: Very Active (Level 4)
#   3–6 hrs: Active (Level 3)
#   > 6–9 hrs: Low Activity (Level 2)
#   > 9 hrs: Sedentary (Level 1)

def recode_activity_minutes(mins):
    if pd.isna(mins):
        return None
    hours = mins / 60.0
    if hours < 3:
        return 'Very Active'
    elif 3 <= hours <= 6:
        return 'Active'
    elif 6 < hours <= 9:
        return 'Low Activity'
    else:
        return 'Sedentary'

df_act['ActivityLevel'] = df_act['PAD680'].apply(recode_activity_minutes)


# -----------------------------
# Step 8: Import PHQ9
# ----------------------------

dpq_dfs = [load_xpt(year, cycle, 'DPQ') for year, cycle in zip(years, cycles)]
df_dpq = pd.concat(dpq_dfs, ignore_index=True)
# Define PHQ-9 items
dpq_cols = [f"DPQ0{i:02d}" for i in range(10, 100, 10)]
# Replace missing codes (7,9) with NaN
for col in dpq_cols:
    df_dpq[col] = pd.to_numeric(df_dpq[col], errors='coerce').replace({7: np.nan, 9: np.nan})
# Calculate total PHQ-9 score
df_dpq['PHQ9'] = df_dpq[dpq_cols].sum(axis=1, min_count=1)
df_phq9 = df_dpq[['SEQN', 'PHQ9']]


# -----------------------------
# Step 9: Import CRP (LBXCRP, LBXHSCRP)
# ----------------------------

crp_frames = []
for y, c in zip(years, cycles):
    if c in ['E', 'F']:
        df_c = load_xpt(y, c, 'CRP')
        var = 'LBXCRP'
    elif c in ['I', 'J']:
        df_c = load_xpt(y, c, 'HSCRP')
        var = 'LBXHSCRP'
    else:
        # skip cycles G, H (2011–2014)
        continue
    temp = df_c[['SEQN', var]].rename(columns={var: 'CRP'})
    crp_frames.append(temp)
df_crp = pd.concat(crp_frames, ignore_index=True)

# -----------------------------
# Step 10: Merge All Datasets (after filtering)
# -----------------------------

df_all = (
    df_demo
    .merge(df_tchol, on='SEQN', how='left')
    .merge(df_smq,  on='SEQN', how='left')
    .merge(df_hgb,  on='SEQN', how='left')
    .merge(df_hr,   on='SEQN', how='left')
    .merge(df_sleep,on='SEQN', how='left')    # <— updated
    .merge(df_act[['SEQN','ActivityLevel']], on='SEQN', how='left')
    .merge(df_phq9, on='SEQN', how='left')
    .merge(df_crp,  on='SEQN', how='left')
)
df_all = df_all.sort_values('SEQN').reset_index(drop=True)

# re-attach the original survey cycle code
df_all = df_all.merge(
    df_demo_raw[['SEQN','SDDSRVYR']],
    on='SEQN', how='left'
)

# keep only the DEMO‐tagged cycle code
df_all = (
    df_all
    .rename(columns={'SDDSRVYR_x': 'SDDSRVYR'})
    .drop(columns=['SDDSRVYR_y'])
)

# Merge All Datasets Before Filtering
# Use raw demographics (no age restriction)
df_all_before = df_demo_raw[['SEQN']].drop_duplicates()
for df in [df_tchol, df_smq, df_hgb, df_hr, df_sleep, df_act[['SEQN', 'ActivityLevel']], df_phq9, df_crp]:
    df_all_before = df_all_before.merge(df, on='SEQN', how='left')


df_all = df_all.sort_values(['Year','SEQN']).reset_index(drop=True)
display(HTML('<h2 style="font-size:20px; margin-bottom:12px;">Merged Dataset Preview (by Year)</h2>'))
# omit the Year column in the preview
display(df_all.drop(columns=['Year']).head(12)) # shows the first two rows of each of the six cycles
# Out:
# <h2 style="font-size:20px; margin-bottom:12px;">Merged Dataset Preview (by Year)</h2>
#        SEQN  RIAGENDR  RIDRETH1  RIDAGEYR  INDFMPIR  SDDSRVYR  LBXTC  SMQ020  \
# 0   41475.0       2.0       5.0      62.0      1.83         5  179.0     2.0
# 1   41479.0       1.0       1.0      52.0      2.20         5  188.0     2.0
# 2   41481.0       1.0       4.0      21.0      1.63         5    NaN     2.0
# 3   41482.0       1.0       1.0      64.0      4.01         5  158.0     1.0
# 4   41485.0       2.0       2.0      30.0      1.01         5  188.0     2.0
# 5   41486.0       2.0       1.0      61.0      1.75         5  194.0     2.0
# 6   41487.0       1.0       5.0      27.0      5.00         5  167.0     2.0
# 7   41489.0       2.0       1.0      40.0      2.15         5  188.0     2.0
# 8   41494.0       1.0       1.0      40.0      1.30         5  223.0     1.0
# 9   41495.0       1.0       3.0      61.0      5.00         5  168.0     1.0
# ...

# %%
#------------------------------------------------
# Overall sample size before and after filtering
#------------------------------------------------

print(f"Sample size before filtering: {df_all_before['SEQN'].nunique()}")
print(f"Sample size after filtering: {df_all['SEQN'].nunique()}")
display(HTML("<br><br>"))

#------------------------------------------------
# Missing data
#------------------------------------------------
# Calculate number and percentage of missing values for each variable

missing = df_all.isnull().sum().to_frame('MissingCount')
missing['Missing%'] = (missing['MissingCount'] / len(df_all)) * 100
# Sort from highest to lowest missing count
missing = missing.sort_values(by='MissingCount', ascending=False)

display(HTML('<h2 style="font-size:20px; font-weight:bold; margin-bottom:12px;">Missing Data Summary (Ranked Highest to Lowest)</h2>'))
display(HTML("<br><br>"))
display(missing)
# Out:
# Sample size before filtering: 59842
# Sample size after filtering: 28610
# <br><br>
# <h2 style="font-size:20px; font-weight:bold; margin-bottom:12px;">Missing Data Summary (Ranked Highest to Lowest)</h2>
# <br><br>
#                MissingCount   Missing%
# CRP                   11421  39.919609
# PHQ9                   3777  13.201678
# INDFMPIR               2821   9.860189
# LBXTC                  2686   9.388326
# LBXHGB                 2410   8.423628
# BPXPLS                 2142   7.486893
# SMQ020                  907   3.170220
# SleepHours               89   0.311080
# ActivityLevel            48   0.167774
# Year                      0   0.000000
# SDDSRVYR                  0   0.000000
# SEQN                      0   0.000000
# RIAGENDR                  0   0.000000
# RIDAGEYR                  0   0.000000
# RIDRETH1                  0   0.000000

# %% [markdown]
# ##**Data characterisation and exploration**

# %%
# Clean Unrealistic Values across all continuous variables
# SleepHours: 0–24 h
df_all.loc[(df_all['SleepHours'] < 0) | (df_all['SleepHours'] > 24), 'SleepHours'] = np.nan
# CRP: 0–50 mg/L
df_all.loc[(df_all['CRP'] < 0) | (df_all['CRP'] > 50), 'CRP'] = np.nan
# PHQ9: 0–27
df_all.loc[(df_all['PHQ9'] < 0) | (df_all['PHQ9'] > 27), 'PHQ9'] = np.nan
# Total cholesterol: 0–1000 mg/dL
df_all.loc[(df_all['LBXTC'] < 0) | (df_all['LBXTC'] > 1000), 'LBXTC'] = np.nan
# Heart rate: 30–200 bpm
df_all.loc[(df_all['BPXPLS'] < 30) | (df_all['BPXPLS'] > 200), 'BPXPLS'] = np.nan
# Haemoglobin: 5–20 g/dL
df_all.loc[(df_all['LBXHGB'] < 5) | (df_all['LBXHGB'] > 20), 'LBXHGB'] = np.nan
# Age: 18–65 (already filtered)

#Continuous Variables Descriptive Statistics with Skew & Kurtosis
tcont_vars = ['RIDAGEYR', 'SleepHours', 'CRP', 'PHQ9', 'LBXTC', 'BPXPLS', 'LBXHGB']
desc_cont = df_all[tcont_vars].describe().T
desc_cont['skewness'] = df_all[tcont_vars].skew().values
desc_cont['kurtosis'] = df_all[tcont_vars].kurtosis().values
display(HTML('<h2 style="font-size:20px; font-weight:bold; margin-bottom:12px;">Continuous Variables Descriptive Stats after Cleaning (including Skewness & Kurtosis)</h2>'))
display(HTML("<br><br>"))
display(desc_cont)
# Out:
# <h2 style="font-size:20px; font-weight:bold; margin-bottom:12px;">Continuous Variables Descriptive Stats after Cleaning (including Skewness & Kurtosis)</h2>
# <br><br>
#               count        mean        std           min           25%  \
# RIDAGEYR    28610.0   41.160538  14.186210  1.800000e+01  2.900000e+01
# SleepHours  28503.0    7.047725   1.513972  0.000000e+00  6.000000e+00
# CRP         17146.0    2.002421   4.141455  1.000000e-02  1.500000e-01
# PHQ9        24833.0    3.386381   4.443189  5.397605e-79  4.857845e-78
# LBXTC       25924.0  191.787417  41.512044  5.900000e+01  1.630000e+02
# BPXPLS      26467.0   73.462047  12.009972  3.600000e+01  6.400000e+01
# LBXHGB      26200.0   14.103733   1.545915  6.100000e+00  1.310000e+01
#
#                50%    75%     max  skewness   kurtosis
# RIDAGEYR     41.00   53.0   65.00  0.003875  -1.222887
# SleepHours    7.00    8.0   14.50  0.062505   0.983385
# CRP           0.53    1.9   49.33  4.982609  34.515929
# ...

# %%
# Frequency Tables for Categorical Variables with Labels
# Include RIAGENDR (Gender), RIDRETH1 (Ethnicity), SMQ020 (EverSmoked), and ActivityLevel

smoke100_map = {1: 'Yes', 2: 'No', 7: 'Refused', 9: "Don't know"}
gender_map   = {1: 'Male', 2: 'Female'}
race_map     = {
    1: 'Mexican American',
    2: 'Other Hispanic',
    3: 'Non-Hispanic White',
    4: 'Non-Hispanic Black',
    5: 'Other'
}

cat_vars = ['RIAGENDR', 'RIDRETH1', 'SMQ020', 'ActivityLevel']

display(HTML('<h2 style="font-size:20px; font-weight:bold; margin-bottom:12px;">Frequency Tables for Categorical Variables</h2>'))
for var in cat_vars:
    # Map codes to labels
    if var == 'RIAGENDR':
        series = df_all[var].map(gender_map);   label = 'Gender'
    elif var == 'RIDRETH1':
        series = df_all[var].map(race_map);     label = 'Ethnicity'
    elif var == 'SMQ020':
        series = df_all[var].map(smoke100_map); label = 'Ever Smoked'
    else:
        series = df_all['ActivityLevel'];       label = 'Activity Level'

    # Build a flat DataFrame
    freq = (
        series
        .value_counts(dropna=False)
        .rename_axis(label)            # name the index axis
        .to_frame('Count')
        .reset_index()                 # turn the index into a column
    )
    freq['Percent %'] = freq['Count'] / len(df_all) * 100

    display(HTML(f"<h3 style='margin-top:20px;'>{label}</h3>"))
    display(freq)
# Out:
# <h2 style="font-size:20px; font-weight:bold; margin-bottom:12px;">Frequency Tables for Categorical Variables</h2>
# <h3 style='margin-top:20px;'>Gender</h3>
#    Gender  Count  Percent %
# 0  Female  14718  51.443551
# 1    Male  13892  48.556449
# <h3 style='margin-top:20px;'>Ethnicity</h3>
#             Ethnicity  Count  Percent %
# 0  Non-Hispanic White  10227  35.746243
# 1  Non-Hispanic Black   6438  22.502621
# 2    Mexican American   4819  16.843761
# 3               Other   3947  13.795876
# 4      Other Hispanic   3179  11.111499
# <h3 style='margin-top:20px;'>Ever Smoked</h3>
#   Ever Smoked  Count  Percent %
# 0          No  16294  56.952115
# 1         Yes  11396  39.832226
# 2         NaN    907   3.170220
# 3  Don't know     10   0.034953
# 4     Refused      3   0.010486
# <h3 style='margin-top:20px;'>Activity Level</h3>
#   Activity Level  Count  Percent %
# 0         Active  12918  45.152045
# 1   Low Activity   5768  20.160783
# 2    Very Active   4965  17.354072
# ...

# %%
import seaborn as sns
import warnings

# Define categorical variables and their labels
categorical_vars = ['RIAGENDR', 'RIDRETH1', 'SMQ020', 'ActivityLevel']
categorical_labels = {
    'RIAGENDR':     'Gender',
    'RIDRETH1':     'Ethnicity',
    'SMQ020':       'Ever Smoked',
    'ActivityLevel':'Activity Level'
}

# Your written interpretations
interpretations = {
    'RIAGENDR': """
Gender (RIAGENDR):
The bar chart shows that the distribution of participants by gender is quite balanced, with a slightly higher number of female participants compared to male participants in the dataset. This indicates good representation of both genders in the sample.
""",
    'RIDRETH1': """
Ethnicity (RIDRETH1):
The bar chart reveals that Non-Hispanic White is the largest ethnic group in the dataset, followed by Non-Hispanic Black, Mexican American, Other, and Other Hispanic. This distribution reflects U.S. population composition to some extent, but it’s important to consider these proportions when interpreting ethnic disparities.
""",
    'SMQ020': """
Ever Smoked (SMQ020):
The chart for smoking status indicates that a larger proportion of participants have **not** smoked at least 100 cigarettes in their lifetime (“No”) compared to those who have (“Yes”). There is also a small percentage of missing data. Smoking is an important confounder in the relationship between biomarkers and depression.
""",
    'ActivityLevel': """
Activity Level (PAD680 → ActivityLevel):
The bar chart shows that the “Active” category has the highest number of participants, followed by “Low Activity,” “Very Active,” and “Sedentary.” There is a very small percentage of missing data. This varied distribution of physical activity levels will help in examining its influence on depressive symptoms and biomarkers.
"""
}

# Map numerical codes to labels for plotting
df_all['RIAGENDR_label']   = df_all['RIAGENDR'].map(gender_map)
df_all['RIDRETH1_label']   = df_all['RIDRETH1'].map(race_map)
df_all['SMQ020_label']     = df_all['SMQ020'].map(smoke100_map)
# ActivityLevel is already string-labeled

# Create grouped bar charts with inline interpretation
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display, HTML

for var in categorical_vars:
    label = categorical_labels[var]

    # build the counts DataFrame
    if var == 'ActivityLevel':
        plot_data = (
            df_all['ActivityLevel']
              .dropna()
              .value_counts()
              .rename_axis(label)
              .reset_index(name='Count')
        )
    else:
        plot_data = (
            df_all[f'{var}_label']
              .dropna()
              .value_counts()
              .rename_axis(label)
              .reset_index(name='Count')
        )

    # prepare colors
    cmap   = plt.get_cmap('tab10')
    colors = cmap(np.linspace(0, 1, len(plot_data)))

    # --- Plot ---
    fig, ax = plt.subplots(figsize=(8,5))
    x_pos = np.arange(len(plot_data))
    ax.bar(x_pos, plot_data['Count'], color=colors, edgecolor='black')
    ax.set_xticks(x_pos)
    ax.set_xticklabels(plot_data[label], rotation=45, ha='right')
    ax.set_title(f'Distribution of {label}')
    ax.set_xlabel(label)
    ax.set_ylabel('Count')
    ax.grid(axis='y', alpha=0.3)
    plt.tight_layout()
    plt.show()


    # --- Styled Interpretation (with bolded heading) ---
    raw_text = interpretations[var].strip().split("\n")
    heading  = raw_text[0].strip('* ')   # e.g. "Gender (RIAGENDR):"
    body     = raw_text[1:]              # the rest of the interpretation lines

# Build HTML: first paragraph is the bold heading, rest are normal text
    html_paragraphs = []
    html_paragraphs.append(f"<p><strong>{heading}</strong></p>")
    for line in body:
      if line.strip():
        html_paragraphs.append(f"<p>{line.strip()}</p>")

    html = f"""
    <div style="
      background-color: #f5f5f5;
      border-left: 4px solid #555;
      color: #222;
      padding: 12px 16px;
      margin-top: 20px;
      margin-bottom: 24px;
      font-size: 14px;
      line-height: 1.6;
    ">
      {''.join(html_paragraphs)}
    </div>
    """
    display(HTML(html))
# Out:
#     <div style="
#       background-color: #f5f5f5;
#       border-left: 4px solid #555;
#       color: #222;
#       padding: 12px 16px;
#       margin-top: 20px;
#       margin-bottom: 24px;
#       font-size: 14px;
#       line-height: 1.6;
#     ">
#       <p><strong>Gender (RIAGENDR):</strong></p><p>The bar chart shows that the distribution of participants by gender is quite balanced, with a slightly higher number of female participants compared to male participants in the dataset. This indicates good representation of both genders in the sample.</p>
#     </div>
#     <div style="
#       background-color: #f5f5f5;
#       border-left: 4px solid #555;
#       color: #222;
#       padding: 12px 16px;
#       margin-top: 20px;
#       margin-bottom: 24px;
#       font-size: 14px;
#       line-height: 1.6;
#     ">
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select numerical columns for correlation analysis
numerical_cols = ['RIDAGEYR', 'SleepHours', 'CRP', 'PHQ9', 'LBXTC', 'BPXPLS', 'LBXHGB']

# Calculate the correlation matrix
correlation_matrix = df_all[numerical_cols].corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap of Numerical Variables')
plt.show()

# %% [markdown]
# ## Correlation Matrix Analysis
#
# 1. **Overall Low Interdependence**
#    - Nearly all off-diagonal values lie between –0.15 and +0.15.
#    - **Takeaway:** This suggests that my seven measures largely vary independently and there is no major multicollinearity.
#
# 2. **Age vs. Cholesterol _(RIDAGEYR ↔ LBXTC ≈ +0.26)_**
#    - **Strongest link** in the matrix.
#    - Older adults have moderately higher total cholesterol, a known clinical pattern.
#
# 3. **Sleep vs. Depression _(SleepHours ↔ PHQ9 ≈ –0.11)_**
#    - Mild **negative** correlation.
#    - More sleep is weakly associated with fewer depressive symptoms.
#
# 4. **Sleep vs. Inflammation _(SleepHours ↔ CRP ≈ +0.12)_**
#    - Small **positive** correlation.
#    - Could reflect “long sleepers” with underlying health issues driving higher CRP.
#
# 5. **Inflammation vs. Heart Rate _(CRP ↔ BPXPLS ≈ +0.12)_**
#    - Slight **positive** link.
#    - Elevated inflammation tends to accompany a faster resting pulse.
#
# 6. **Depression vs. Heart Rate _(PHQ9 ↔ BPXPLS ≈ +0.10)_**
#    - Modest **positive** correlation.
#    - Higher PHQ-9 scores go hand-in-hand with marginally elevated heart rate.
#
# 7. **Haemoglobin Stands Alone _(LBXHGB correlations ≈ 0)_**
#    - All correlations with LBXHGB fall near zero (largest ~+0.11 with LBXTC).
#    - Suggests hemoglobin levels are largely unrelated to mood, sleep, or inflammation here.
#
# ---
#
# ### Practical Implications
#
# - **Modeling:**
#   - Low pairwise correlations means that I can include multiple biomarkers in the same regression without severe multicollinearity concerns.
#
# - **Hypothesis Generation:**
#   - The age–cholesterol link invites age-stratified lipid analyses.
#   - The sleep–depression and sleep–CRP signals suggest exploring whether sleep interventions could impact mood or inflammation.

# %%
# Shapiro–Wilk Normality Tests for Continuous Variables
from scipy.stats import shapiro
import warnings

# ignore only the "N > 5000" Shapiro warning
warnings.filterwarnings(
    "ignore",
    message=".*scipy\\.stats\\.shapiro: For N > 5000, computed p-value may not be accurate.*"
)


cont_vars = ['RIDAGEYR', 'SleepHours', 'CRP', 'PHQ9', 'LBXTC', 'BPXPLS', 'LBXHGB']
display(HTML('<h2 style="font-size:20px; font-weight:bold; margin-bottom:12px;">Shapiro–Wilk Test Results with Normality Indicator</h2>'))
shapiro_results = {}
for var in cont_vars:
    data = df_all[var].dropna()
    if len(data) >= 3:  # minimum n for Shapiro
        stat, p = shapiro(data)
        shapiro_results[var] = {'W-statistic': stat, 'p-value': p}
    else:
        shapiro_results[var] = {'W-statistic': np.nan, 'p-value': np.nan}
results_df = pd.DataFrame(shapiro_results).T

# Add column indicating normality at alpha=0.05
results_df['NormalDist'] = results_df['p-value'] > 0.05
display(results_df)

# prepare
df_plot = (results_df
  .reset_index()
  .rename(columns={'index':'Variable'})
  .assign(negLog10p = lambda d: -np.log10(d['p-value']))
)

vars_   = df_plot['Variable']
heights = df_plot['negLog10p']
colors  = ['green' if ok else 'red' for ok in df_plot['NormalDist']]

# plot
fig, ax = plt.subplots(figsize=(8,4))
ax.bar(vars_, heights, color=colors, edgecolor='black', linewidth=0.5)

# α = 0.05 threshold line
threshold = -np.log10(0.05)  # ≈ 1.301
ax.axhline(threshold, color='gray', linestyle='--', linewidth=1, label='α = 0.05')

# labels & styling
ax.set_title('Shapiro–Wilk Test: –log₁₀(p-value) (green=normal, red=non-normal)')
ax.set_ylabel('-log₁₀(p-value)')
ax.set_xticks(vars_)
ax.set_xticklabels(vars_, rotation=45, ha='right')
ax.legend(loc='upper right')

plt.tight_layout()
plt.show()
# Out:
# <h2 style="font-size:20px; font-weight:bold; margin-bottom:12px;">Shapiro–Wilk Test Results with Normality Indicator</h2>
#             W-statistic        p-value  NormalDist
# RIDAGEYR       0.949641   2.176892e-69       False
# SleepHours     0.963348   8.252533e-63       False
# CRP            0.484139  6.980914e-113       False
# PHQ9           0.754925  3.758585e-103       False
# LBXTC          0.969077   8.947438e-58       False
# BPXPLS         0.979001   5.656039e-51       False
# LBXHGB         0.989540   3.798495e-39       False

# %%
import math
import re

# Define your numerical variables
num_vars = ["RIDAGEYR", "SleepHours", "CRP", "PHQ9", "LBXTC", "BPXPLS", "LBXHGB"]

# Prepare for summaries
summaries = []

# Configure subplot grid
n_cols = 3
n_vars = len(num_vars)
n_rows = math.ceil(n_vars / n_cols)

fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols * 5, n_rows * 4))
axes = axes.flatten()

# Loop through variables and plot
for idx, var in enumerate(num_vars):
    ax = axes[idx]
    if var in df_all:
        data = df_all[var].dropna()

        # Apply variable-specific filters
        if var == "SleepHours":
            data = data[(data >= 0) & (data <= 24)]
        elif var == "CRP":
            data = data[(data >= 0) & (data <= 50)]

        # Skip empty data
        if data.empty:
            ax.set_visible(False)
            continue

        # Compute histogram
        counts, bin_edges = np.histogram(data, bins=40)
        max_idx = counts.argmax()
        max_count = counts[max_idx]
        max_range = (bin_edges[max_idx], bin_edges[max_idx + 1])

        # Plot on the subplot
        ax.hist(data, bins=40, edgecolor='black', color='skyblue')
        ax.set_title(f"Histogram of {var}")
        ax.set_xlabel(var)
        ax.set_ylabel("Frequency")
        ax.grid(axis='y', linestyle='--', alpha=0.5)

        # Store summary
        summaries.append(
            f"{var}: Highest frequency bin is {max_range[0]:.2f} to {max_range[1]:.2f} with {max_count} observations."
        )
    else:
        ax.set_visible(False)

# Hide any unused subplots
for j in range(n_vars, n_rows * n_cols):
    axes[j].set_visible(False)

plt.tight_layout()
plt.show()

# Print summaries

rows = []
for s in summaries:
    var, rest = s.split(":", 1)
    m = re.search(r"bin is ([0-9\.]+\s*to\s*[0-9\.]+) with (\d+)", rest)
    if m:
        bin_range, count = m.group(1), int(m.group(2))
    else:
        bin_range, count = rest.strip(), None
    rows.append({"Variable": var, "BinRange": bin_range, "Count": count})

df_summary = pd.DataFrame(rows)

# 2) Style it: make the BinRange text navy and the Count text dark red
styled = (
    df_summary
    .style
    .set_properties(subset=["BinRange"], **{"color": "skyblue", "font-weight": "bold"})
    .set_properties(subset=["Count"],    **{"color": "red"})
    .set_table_styles([
        {"selector": "th", "props": [("font-size","16px"), ("text-align","left")]},
        {"selector": "td", "props": [("padding","6px"), ("text-align","left")]}
    ])
)

display(styled)
# Out:
# <style type="text/css">
# #T_1c84b th {
#   font-size: 16px;
#   text-align: left;
# }
# #T_1c84b td {
#   padding: 6px;
#   text-align: left;
# }
# #T_1c84b_row0_col1, #T_1c84b_row1_col1, #T_1c84b_row2_col1, #T_1c84b_row3_col1, #T_1c84b_row4_col1, #T_1c84b_row5_col1, #T_1c84b_row6_col1 {
#   color: skyblue;
#   font-weight: bold;
# }
# #T_1c84b_row0_col2, #T_1c84b_row1_col2, #T_1c84b_row2_col2, #T_1c84b_row3_col2, #T_1c84b_row4_col2, #T_1c84b_row5_col2, #T_1c84b_row6_col2 {
#   color: red;
# }
# </style>
# <table id="T_1c84b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c84b_level0_col0" class="col_heading level0 col0" >Variable</th>
#       <th id="T_1c84b_level0_col1" class="col_heading level0 col1" >BinRange</th>
#       <th id="T_1c84b_level0_col2" class="col_heading level0 col2" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c84b_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
#Q–Q Plots for Continuous Variables
from scipy import stats

display(HTML('<h2 style="font-size:20px; font-weight:bold; margin-bottom:12px;">Q–Q Plots for Continuous Variables</h2>'))
# Determine grid size (e.g. 3 columns)
n = len(cont_vars)
cols = 3
rows = int(np.ceil(n/cols))

fig, axes = plt.subplots(rows, cols, figsize=(cols*5, rows*4))
axes = axes.flatten()

for ax, var in zip(axes, cont_vars):
    data = df_all[var].dropna()
    # Q–Q plot
    stats.probplot(data, dist="norm", plot=ax)
    ax.get_lines()[1].set_color('red')       # make the fit line red
    ax.set_title(f"Q–Q Plot of {var}")
    ax.tick_params(axis='both', which='major', labelsize=10)
    # tighten the axis range to the 1st/99th percentile
    lo, hi = np.percentile(data, [1, 99])
    ax.set_xlim(stats.norm.ppf(0.01), stats.norm.ppf(0.99))
    ax.set_ylim(lo, hi)
    # improve marker style
    for line in ax.get_lines():
        line.set_marker('.')
        line.set_markersize(4)
        line.set_alpha(0.6)

# hide any empty subplots
for ax in axes[n:]:
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# <h2 style="font-size:20px; font-weight:bold; margin-bottom:12px;">Q–Q Plots for Continuous Variables</h2>

# %% [markdown]
# ### Q–Q Plot Observations
#
# | Variable   | Q–Q Pattern                        | Practical Normality? |
# |------------|------------------------------------|----------------------|
# | RIDAGEYR   | Small tail deviations              | Yes, minor           |
# | SleepHours | Step-like clusters; right tail     | No, clear skew       |
# | CRP        | Strong S-shape; heavy right tail   | No                   |
# | PHQ9       | Right-skew; heavy upper quantiles  | No                   |
# | LBXTC      | Mild right-skew at high values     | Yes, mild            |
# | BPXPLS     | Points tightly on line             | Yes                  |
# | LBXHGB     | Near-perfect alignment             | Yes                  |

# %% [markdown]
# ### Interpretation of data normality

# %% [markdown]
# 1. Shapiro–Wilk on the full data
#    - Every continuous variable gave Shapiro–Wilk p < 0.05. In a sample of ~60 000, the test flags even tiny tail departures as “significant,” so this tells us only that our distributions are all not normal
#
# 2. Histograms & Q–Q plots (1st–99th percentile zoom)
#    - Haemoglobin, Heart Rate, Cholesterol, Age – Visually bell-shaped in the centre, Q–Q points hug the line for most of the range. A few extreme tails remain, but the middle 95–98 % looks approximately normal
#    - CRP, PHQ-9, SleepHours – Even after dropping the extreme 1 % on each side, the histograms stay skewed and the Q–Q plots bend away from the line which is clear evidence of heavy tails
#
#
# 3. Conclusion
#    1. Variables with “trivial deviations” (Hb, heart rate, cholesterol) – Safe to treat as approximately normal in most regression or ANOVA models (after excluding outliers)
#    2. Variables that remain non-normal (CRP, PHQ-9, SleepHours) – Either transform (e.g. log-transform CRP) or use non-parametric methods (e.g. Spearman correlations, Wilcoxon tests) when strict distributional assumptions are needed

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# Define your numerical variables
num_vars = ["RIDAGEYR", "SleepHours", "CRP", "PHQ9", "LBXTC", "BPXPLS", "LBXHGB"]

# Configure subplot grid
n_cols = 3
n_vars = len(num_vars)
n_rows = math.ceil(n_vars / n_cols)

fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols * 5, n_rows * 4))
axes = axes.flatten()

# Loop through variables and plot boxplots
for idx, var in enumerate(num_vars):
    ax = axes[idx]
    if var in df_all:
        data = df_all[var].dropna()

        # Apply variable-specific filters
        if var == "SleepHours":
            data = data[(data >= 0) & (data <= 24)]
        elif var == "CRP":
            data = data[(data >= 0) & (data <= 50)]

        # Skip if no data
        if data.empty:
            ax.set_visible(False)
            continue

        # Plot boxplot
        ax.boxplot(data, patch_artist=True,
                   boxprops=dict(facecolor='skyblue', edgecolor='black'),
                   medianprops=dict(color='red'),
                   flierprops=dict(marker='o', markerfacecolor='gray', alpha=0.5))
        ax.set_title(f"Boxplot of {var}")
        ax.set_xlabel(var)
        ax.set_ylabel("Value")
        ax.grid(axis='y', linestyle='--', alpha=0.5)
    else:
        ax.set_visible(False)

# Hide any unused subplots
for j in range(n_vars, n_rows * n_cols):
    axes[j].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Interpretation of boxplots**
#
# **RIDAGEYR**: Relatively symmetrical distribution
#
# **SleepHours**: Left-skewed distribution with outliers at lower sleep durations, indicating a tendency for most people to sleep around 7-8 hours, but some report significantly less.
#
# **CRP**: Highly right-skewed with many outliers at high values, indicating that while most individuals have low CRP, a substantial number have elevated or very high levels.
#
# **PHQ9**: Right-skewed distribution with a concentration of scores at the lower end and outliers representing higher depression severity.
#
# **LBXTC**: Mostly symmetrical distribution with some outliers on both low and high ends.
#
# **BPXPLS**: Slightly right-skewed with some outliers at the extremes, generally centered within the normal range.
#
# **LBXHGB**: Close to symmetrical distribution with minimal outliers, suggesting a relatively normal distribution of haemoglobin levels.

# %%
# now that SDDSRVYR lives in df_all, you can group on it:
sleep_summary = (
    df_all
      .groupby('SDDSRVYR')['SleepHours']
      .agg(['count','median'])
      .reindex([5,6,7,8,9,10], fill_value=0)
)
print(sleep_summary)


trend_vars = ['PHQ9','SleepHours','BPXPLS','CRP','LBXHGB','LBXTC','RIDAGEYR']
df_annual = (
    df_all
      .dropna(subset=['Year'])
      .groupby('Year')[trend_vars]
      .median()
      .reset_index()
)

# 5) Plot with real cycle years on every x-axis
n = len(trend_vars)
cols = 3
rows = int(np.ceil(n/cols))
fig, axes = plt.subplots(rows, cols, figsize=(cols*5, rows*4), sharex=False)

for idx, var in enumerate(trend_vars):
    ax = axes.flatten()[idx]
    ax.plot(df_annual['Year'], df_annual[var], marker='o', linestyle='-')
    ax.set_title(f'Annual Median of {var}')
    ax.set_xlabel('Survey Cycle Year')
    ax.set_ylabel(var)
    ax.set_xticks(df_annual['Year'])                   # ensure these labels show
    ax.set_xticklabels(df_annual['Year'].astype(str), rotation=45)
    ax.grid(alpha=0.3)

# hide extra panels
for ax in axes.flatten()[n:]:
    ax.axis('off')

plt.subplots_adjust(bottom=0.15, hspace=0.4)  # give more room for labels
plt.show()
# Out:
#           count  median
# SDDSRVYR
# 5          4750     7.0
# 6          5086     7.0
# 7          4701     7.0
# 8          4884     7.0
# 9          4683     7.5
# 10         4399     7.5

# %% [markdown]
# ### Interpretation for Annual Median Trends
#
# **PHQ9**: The plot shows that the median PHQ9 score remained relatively low and stable across the survey years. There are minor fluctuations, but no clear upward or downward trend in the median depression severity is apparent in this age group over this period.
#
# **SleepHours**: The median sleep hours show a slight upward trend from around 7.0 hours in earlier cycles to around 7.5 hours in the later cycles (2015-2018). This suggests a small increase in the median self-reported sleep duration among participants aged 18-65 over the study period.
#
# **BPXPLS**: The median resting heart rate appears to be relatively stable across the survey years, hovering around the mid-70s bpm. There are minor variations from year to year, but no significant increasing or decreasing trend is evident.
#
# **CRP**: The median CRP levels show variability across the years for which data is available (2007-2008 and 2015-2018). There isn't a consistent trend visible across the entire period due to the data gaps. However, within the available years, the median appears to fluctuate.
# **LBXHGB** : The median haemoglobin levels show a relatively stable trend across the survey years. There are small fluctuations, but the median remains consistently within the normal range for adults throughout the study period.
#
# **LBXTC**: The median total cholesterol levels show a slight downward trend over the survey years. While fluctuating, the overall pattern suggests a modest decrease in median cholesterol among the sampled population from 2007 to 2017.
#
# **RIDAGEYR**: This plot shows the median age of the participants included in my filtered dataset (18-65) for each survey year. The median age remains relatively stable across the years, hovering around the low to mid-40s, which is expected given my age inclusion criteria.

# %%
# 1. Compute annual depression prevalence
dep_summary = (
    df_all
    .dropna(subset=['Year','PHQ9'])                     # only rows with a PHQ9 score
    .groupby('Year')['PHQ9']
    .agg(Total='count', Depressed=lambda s: (s > 10).sum())
    .reset_index()
)
dep_summary['PercentDepressed'] = dep_summary['Depressed'] / dep_summary['Total'] * 100

# 2. Show the table
display(HTML('<h3 style="margin-top:20px;">Annual Depression Prevalence (PHQ-9 > 10)</h3>'))
display(dep_summary[['Year','Total','Depressed','PercentDepressed']].style.format({
    'PercentDepressed': '{:.1f}%'
}))

# 3. Plot the trend
plt.figure(figsize=(6,4))
plt.plot(
    dep_summary['Year'],
    dep_summary['PercentDepressed'],
    marker='o',
    linestyle='-',
    linewidth=2
)
plt.title('Annual % of Participants with PHQ-9 > 10')
plt.xlabel('Survey Cycle Year')
plt.ylabel('Percent Depressed')
plt.xticks(dep_summary['Year'], [str(int(y)) for y in dep_summary['Year']], rotation=45)
plt.ylim(0, dep_summary['PercentDepressed'].max()*1.1)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# <h3 style="margin-top:20px;">Annual Depression Prevalence (PHQ-9 > 10)</h3>
# <style type="text/css">
# </style>
# <table id="T_efcea" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_efcea_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_efcea_level0_col1" class="col_heading level0 col1" >Total</th>
#       <th id="T_efcea_level0_col2" class="col_heading level0 col2" >Depressed</th>
#       <th id="T_efcea_level0_col3" class="col_heading level0 col3" >PercentDepressed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_efcea_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_efcea_row0_col0" class="data row0 col0" >2007</td>
#       <td id="T_efcea_row0_col1" class="data row0 col1" >4201</td>
#       <td id="T_efcea_row0_col2" class="data row0 col2" >386</td>
#       <td id="T_efcea_row0_col3" class="data row0 col3" >9.2%</td>
#     </tr>
#     <tr>
# ...

# %%
# Define biomarker thresholds
biomarker_thresholds = {
    'SleepHours': {'min': None, 'max': 6, 'or_min': 9, 'or_max': None}, # <6 or >9
    'BPXPLS': {'min': None, 'max': 60, 'or_min': 100, 'or_max': None}, # <60 or >100
    'CRP': {'min': 3, 'max': None}, # >3
    'LBXTC': {'min': None, 'max': 125, 'or_min': 200, 'or_max': None}, # ~125-200 normal, so <125 or >200 abnormal
    'LBXHGB': {'male_min': None, 'male_max': 13.5, 'female_min': None, 'female_max': 12.0} # <13.5 (men), <12.0 (women)
}
# Initialize a dictionary to store results
abnormal_percentages = {}

# Get the total number of sampled persons
total_sampled = len(df_all)

# Iterate through each biomarker and its thresholds
for biomarker, thresholds in biomarker_thresholds.items():
    if biomarker == 'LBXHGB':
        # Handle gender-specific thresholds for Haemoglobin
        male_abnormal_count = df_all[
            (df_all['RIAGENDR'] == 1) &
            (df_all[biomarker] < thresholds['male_max'])
        ].shape[0]
        female_abnormal_count = df_all[
            (df_all['RIAGENDR'] == 2) &
            (df_all[biomarker] < thresholds['female_max'])
        ].shape[0]
        abnormal_count = male_abnormal_count + female_abnormal_count
    else:
        # Handle other biomarkers with min/max/or_min/or_max thresholds
        condition = pd.Series(False, index=df_all.index)

        if thresholds.get('min') is not None:
            condition = condition | (df_all[biomarker] > thresholds['min'])
        if thresholds.get('max') is not None:
            condition = condition | (df_all[biomarker] < thresholds['max'])
        if thresholds.get('or_min') is not None:
            condition = condition | (df_all[biomarker] > thresholds['or_min'])
        if thresholds.get('or_max') is not None:
            condition = condition | (df_all[biomarker] < thresholds['or_max'])

        # Ensure we only count non-missing values
        abnormal_count = df_all[condition & df_all[biomarker].notna()].shape[0]

    # Calculate percentage and store
    abnormal_percentage = (abnormal_count / total_sampled) * 100
    abnormal_percentages[biomarker] = abnormal_percentage

display(HTML('<h2 style="font-size:20px; font-weight:bold; margin-bottom:12px;">Percentage of Sampled Persons with Abnormal Biomarker Levels</h2>'))
# Create a DataFrame for display
abnormal_df = pd.DataFrame(list(abnormal_percentages.items()), columns=['Biomarker', 'Percentage Abnormal (%)'])
display(abnormal_df)

fig, ax = plt.subplots(figsize=(6,4))

# simple bar plot
bars = ax.bar(
    abnormal_df['Biomarker'],
    abnormal_df['Percentage Abnormal (%)'],
    edgecolor='black',
    linewidth=0.8
)

# add value labels
for bar in bars:
    h = bar.get_height()
    ax.text(
        bar.get_x() + bar.get_width()/2,
        h + 0.5,
        f"{h:.1f}%",
        ha='center',
        va='bottom',
        fontsize=10
    )

# fix ticks and labels in one go
ax.set_xticks(range(len(abnormal_df)))
ax.set_xticklabels(abnormal_df['Biomarker'], rotation=45, ha='right')

# styling
ax.set_title('Percent of Sample with Abnormal Biomarker Levels')
ax.set_ylabel('Percentage Abnormal (%)')
ax.set_ylim(0, abnormal_df['Percentage Abnormal (%)'].max() * 1.2)
ax.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# <h2 style="font-size:20px; font-weight:bold; margin-bottom:12px;">Percentage of Sampled Persons with Abnormal Biomarker Levels</h2>
#     Biomarker  Percentage Abnormal (%)
# 0  SleepHours                19.080741
# 1      BPXPLS                10.887801
# 2         CRP                10.664103
# 3       LBXTC                37.294652
# 4      LBXHGB                 9.363859

# %% [markdown]
# ## References
#
# Cepeda, M.S., Stang, P. and Makadia, R. (2016) 'Depression is associated with high levels of C-Reactive protein and low levels of fractional exhaled nitric oxide,' The Journal of Clinical Psychiatry, 77(12), pp. 1666–1671. https://doi.org/10.4088/jcp.15m10267.
#
# Howren, M.B., Lamkin, D.M. and Suls, J. (2009) 'Associations of depression with C-Reactive Protein, IL-1, and IL-6: A Meta-Analysis,' Psychosomatic Medicine, 71(2), pp. 171–186. https://doi.org/10.1097/psy.0b013e3181907c1b.
#
# Kroenke, K., Spitzer, R.L. and Williams, J.B.W. (2001) 'The PHQ-9,' Journal of General Internal Medicine, 16(9), pp. 606–613. https://doi.org/10.1046/j.1525-1497.2001.016009606.x.
